# %% [markdown]
# ## Big O Notation

# %%
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
x = range(0,100)

# Define each function using list comprehensions
O1 = [1 for n in x]
Ologn = [math.log(n) if n>0 else np.nan for n in x]
On = x
Onlogn = [n * math.log(n) if n>0 else np.nan for n in x]
On2 = [n**2 for n in x]
O2n = [2**n for n in x]
Onfact = [math.factorial(int(n))for n in x] # converts non integer values to integers - results in step plot
Onn = [n**n for n in x]

# Increase figure size for better visual
plt.rcParams['figure.figsize'] = [10, 7]

# Set axis limits to see detail at lower x values
plt.xlim(0,10)
plt.ylim(0,100)

# plt.figure(figsize = (12,8)) Enabling this caused weird conflicts with setting axis limits. Better to set size using the rcParams above

plt.title('Big O Notation (linear scale)')
plt.xlabel('Elements')
plt.ylabel('Operations')

plt.plot(x,O1, label = 'O(1)')
plt.plot(x,Ologn, label = 'O($\log{n}$)')
plt.plot(x,On, label = 'O(n)')
plt.plot(x,Onlogn, label = 'O(n $\log{n}$)')
plt.plot(x,On2, label = 'O(${n^2}$)')
plt.plot(x,O2n, label = 'O(${2^n}$)')
plt.plot(x,Onfact, label = 'O(${n!}$)')
plt.plot(x, Onn, label = 'O(${n^n}$)')

plt.legend(loc='upper right')

# %% [markdown]
# ### Write my name (BONUS) - block letters

# %%
globalymax = 10
globalymin = 1

# J
plt.hlines(y = 1, xmin = 2, xmax = 3)
plt.hlines(y = globalymax, xmin = 2, xmax = 4)
plt.vlines(x = 3, ymin = globalymin, ymax = globalymax)
plt.vlines(x = 2, ymin = globalymin, ymax = 4)

# E
plt.vlines(x = 5, ymin = globalymin, ymax= globalymax)
plt.hlines(y = globalymax, xmin = 5, xmax = 6)
plt.hlines(y = (globalymax+globalymin)/2, xmin = 5, xmax = 6)
plt.hlines(y = globalymin, xmin = 5, xmax = 6)

# S

plt.hlines(y = globalymax, xmin=7, xmax = 8)
plt.hlines(y = (globalymax+globalymin)/2, xmin=7, xmax = 8)
plt.hlines(y = globalymin, xmin=7, xmax = 8)
plt.vlines(x = 7, ymin = (globalymax+globalymin)/2, ymax = globalymax)
plt.vlines(x = 8, ymin = globalymin, ymax = (globalymax+globalymin)/2)

# S

plt.hlines(y = globalymax, xmin=9, xmax = 10)
plt.hlines(y = (globalymax+globalymin)/2, xmin=9, xmax = 10)
plt.hlines(y = globalymin, xmin=9, xmax = 10)
plt.vlines(x = 9, ymin = (globalymax+globalymin)/2, ymax = globalymax)
plt.vlines(x = 10, ymin = globalymin, ymax = (globalymax+globalymin)/2)

# E
plt.vlines(x = 11, ymin = globalymin, ymax= globalymax)
plt.hlines(y = globalymax, xmin = 11, xmax = 12)
plt.hlines(y = (globalymax+globalymin)/2, xmin = 11, xmax = 12)
plt.hlines(y = globalymin, xmin = 11, xmax = 12)

# %% [markdown]
# ### Write my name (BONUS) - curves

# %%
import matplotlib.path as mpath
import matplotlib.patches as mpatches

# %%
Path = mpath.Path

fig, ax = plt.subplots()

#J
pp1 = mpatches.PathPatch(
    Path([(1, 2), (2,1), (3, 2), (3, 5)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.LINETO]),
    fc="none")

ax.hlines(y=5, xmin = 2, xmax = 4)

#e
pp2 = mpatches.PathPatch(
    Path([(6, 3), (8,3), (7, 4), (6, 4), (6,3), (7,2), (8,2)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3]),
    fc="none")

# s
pp3 = mpatches.PathPatch(
    Path([(12, 4), (10,3.5), (11, 3), (12, 2.5), (11,2), (10,2.5), (10,2.5)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3]),
    fc="none")
# s
pp4 = mpatches.PathPatch(
    Path([(15, 4), (13,3.5), (14, 3), (15, 2.5), (14,2), (13,2.5), (13,2.5)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3]),
    fc="none")

# e
pp5 = mpatches.PathPatch(
    Path([(18, 3), (20,3), (19, 4), (18, 4), (18,3), (19,2), (20,2)],
         [Path.MOVETO, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3, Path.CURVE3]),
    fc="none")

ax.add_patch(pp1)
ax.add_patch(pp2)
ax.add_patch(pp3)
ax.add_patch(pp4)
ax.add_patch(pp5)

ax.grid()

ax.set_xlim(0,20)
ax.set_ylim(0,6)

plt.show()
