# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Use matplotlib to plot the following equation:
#
# y =x^2−x+2
#
# Add an anotation for the point 0, 0, the origin.

# %%
x = range(-100,100)
y =[x**2 - x + 2 for x in x]

# %%
plt.title('Exercise 1')
plt.annotate('Origin', xy=(0, 0), xytext=(0, 2000),
             arrowprops={'facecolor': 'blue'})
plt.plot(x,y)

# %% [markdown]
# Create and label 4 separate charts for given equations.
# You can use functions from the math module to help implement some of the equations above.

# %%
import math

xsqrt = range(0,100)
ysqrt = [math.sqrt(x) for x in xsqrt]

plt.title('$\sqrt{x}$')
plt.plot(xsqrt,ysqrt)

# %%
xcube = range(-100,100)
ycube = [x**3 for x in xcube]

plt.title('$x^3$')
plt.plot(xcube,ycube)

# %%
xpow2 = range(-100,100)
ypow2 = [2**x for x in xpow2]

plt.title('$2^x$')
plt.plot(xpow2,ypow2)

# %%
x = range(-100,100)
y = [(1/(n+1)) if n != -1 else np.nan for n in x ]
plt.title('$frac{1}{x+1}$')
plt.plot(x,y)

# %% [markdown]
# 3.
# Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize = (12,8))
# plot the first subplot
plt.subplot(221)
plt.plot(xsqrt, ysqrt)
plt.title('Sqrt x')

# the second subplot
plt.subplot(222)
plt.plot(xcube, ycube)
plt.title('x ^ 3')

# plot the third subplot
plt.subplot(223)
plt.plot(xpow2, ypow2)
plt.title('2^x')

# the fourth subplot
plt.subplot(224)
plt.plot(x, y)
plt.title('1/(x+1)')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/tt/99v8dp0d60sfw82fs51dhr4m0000gn/T/ipykernel_21308/308969022.py in <module>
#       2 # plot the first subplot
#       3 plt.subplot(221)
# ----> 4 plt.plot(xsqrt, ysqrt)
#       5 plt.title('Sqrt x')
#       6
#
# NameError: name 'xsqrt' is not defined

# %% [markdown]
# #### 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
x = range(0,10)

ysqrt = [math.sqrt(x) for x in x]

ycube = [x**3 for x in x]

ypow2 = [2**x for x in x]

y = [(1/(x+1)) for x in x]

plt.plot(x, ysqrt)

plt.plot(x, ycube)

plt.plot(x, ypow2)

plt.plot(x, y)
plt.title('Combined Plots')

plt.show()

# %%
x=range(-100,100)
import math

# %%
y = [math.sqrt(n) if n>0 else np.nan for n in x]

# %%
y
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  1.0,
#  1.4142135623730951,
#  1.7320508075688772,
#  2.0,
#  2.23606797749979,
#  2.449489742783178,
#  2.6457513110645907,
#  2.8284271247461903,
#  3.0,
#  3.1622776601683795,
#  3.3166247903554,
#  3.4641016151377544,
#  3.605551275463989,
#  3.7416573867739413,
#  3.872983346207417,
#  4.0,
#  4.123105625617661,
#  4.242640687119285,
#  4.358898943540674,
#  4.47213595499958,
#  4.58257569495584,
#  4.69041575982343,
#  4.795831523312719,
#  4.898979485566356,
#  5.0,
#  5.0990195135927845,
#  5.196152422706632,
#  5.291502622129181,
#  5.385164807134504,
#  5.477225575051661,
#  5.5677643628300215,
#  5.656854249492381,
#  5.744562646538029,
#  5.830951894845301,
#  5.916079783099616,
#  6.0,
#  6.082762530298219,
#  6.164414002968976,
#  6.244997998398398,
#  6.324555320336759,
#  6.4031242374328485,
#  6.48074069840786,
#  6.557438524302,
#  6.6332495807108,
#  6.708203932499369,
#  6.782329983125268,
#  6.855654600401044,
#  6.928203230275509,
#  7.0,
#  7.0710678118654755,
#  7.14142842854285,
#  7.211102550927978,
#  7.280109889280518,
#  7.3484692283495345,
#  7.416198487095663,
#  7.483314773547883,
#  7.54983443527075,
#  7.615773105863909,
#  7.681145747868608,
#  7.745966692414834,
#  7.810249675906654,
#  7.874007874011811,
#  7.937253933193772,
#  8.0,
#  8.06225774829855,
#  8.12403840463596,
#  8.18535277187245,
#  8.246211251235321,
#  8.306623862918075,
#  8.366600265340756,
#  8.426149773176359,
#  8.48528137423857,
#  8.54400374531753,
#  8.602325267042627,
#  8.660254037844387,
#  8.717797887081348,
#  8.774964387392123,
#  8.831760866327848,
#  8.888194417315589,
#  8.94427190999916,
#  9.0,
#  9.055385138137417,
#  9.1104335791443,
#  9.16515138991168,
#  9.219544457292887,
#  9.273618495495704,
#  9.327379053088816,
#  9.38083151964686,
#  9.433981132056603,
#  9.486832980505138,
#  9.539392014169456,
#  9.591663046625438,
#  9.643650760992955,
#  9.695359714832659,
#  9.746794344808963,
#  9.797958971132712,
#  9.848857801796104,
#  9.899494936611665,
#  9.9498743710662]
