# %% [markdown]
# Exercises from https://ds.codeup.com/python/dataframes/

# %%
from pydataset import data

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %%
df
# Out:
#        name  math  english  reading
# 0     Sally    62       85       80
# 1      Jane    88       79       67
# 2     Suzie    94       74       95
# 3     Billy    98       96       88
# 4       Ada    77       92       98
# 5      John    79       76       93
# 6    Thomas    82       64       81
# 7     Marie    93       63       90
# 8    Albert    92       62       87
# 9   Richard    69       80       94
# 10    Isaac    92       99       93
# 11     Alan    92       62       72

# %% [markdown]
# a. Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
df["passing_english"] = df.english > 70

# %% [markdown]
# b. Sort the english grades by the passing_english column. How are duplicates handled?

# %%
df.sort_values("passing_english")

# duplicates appear to be sorted by "name" column descending 
# or else index column ascending
# Out:
#        name  math  english  reading  passing_english
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# c. Sort the english grades first by passing_english and then by student name. All the students that are failing english should be first, and within the students that are failing english they should be ordered alphabetically. The same should be true for the students passing english. (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(by=["passing_english","name"])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %% [markdown]
# d. Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(by = ["passing_english","english"])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %% [markdown]
# e. Calculate each students overall grade and add it as a column on the dataframe. The overall grade is the average of the math, english, and reading grades.

# %%
df.assign(overall_grade=sum([df.english, df.reading, df.math])/3)
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 0     Sally    62       85       80             True      75.666667
# 1      Jane    88       79       67             True      78.000000
# 2     Suzie    94       74       95             True      87.666667
# 3     Billy    98       96       88             True      94.000000
# 4       Ada    77       92       98             True      89.000000
# 5      John    79       76       93             True      82.666667
# 6    Thomas    82       64       81            False      75.666667
# 7     Marie    93       63       90            False      82.000000
# 8    Albert    92       62       87            False      80.333333
# 9   Richard    69       80       94             True      81.000000
# 10    Isaac    92       99       93             True      94.666667
# 11     Alan    92       62       72            False      75.333333

# %% [markdown]
# Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:

# %%
mpg = data("mpg",show_doc= True)
mpg = data("mpg")
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# How many rows and columns are there?

# %%
# Docs state it's a data frame with 234 rows and 11 variables
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# What are the data types of each column?

# %%
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# Rename the cty column to city.

# %%
mpg.rename(columns = {'cty':'city'}, inplace = True)

# %% [markdown]
# Rename the hwy column to highway.

# %%
mpg.rename(columns = {'hwy':'highway'}, inplace = True)

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# Do any cars have better city mileage than highway mileage?

# %%
mpg[mpg.city>mpg.highway]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class]
# Index: []

# %% [markdown]
# Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city

# %% [markdown]
# Which car (or cars) has the highest mileage difference?

# %%
mpg[mpg.mileage_difference == max(mpg.mileage_difference)]
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
#
#     fl       class  mileage_difference
# 107  c  subcompact                  12
# 223  d  subcompact                  12

# %% [markdown]
# Which compact class car has the lowest highway mileage? The best?

# %%
print(f"Compact class car with lowest highway mileage is:\n{mpg[mpg['class'] == 'compact'].sort_values('highway').iloc[0]}")
print(f"\n---\nCompact class car with best highway mileage is: \n{mpg[mpg['class'] == 'compact'].sort_values('highway').iloc[-1]}")
# Out:
# Compact class car with lowest highway mileage is:
# manufacturer          volkswagen
# model                      jetta
# displ                        2.8
# year                        1999
# cyl                            6
# trans                   auto(l4)
# drv                            f
# city                          16
# highway                       23
# fl                             r
# class                    compact
# mileage_difference             7
# average_mileage             19.5
# Name: 220, dtype: object
#
# ---
# Compact class car with best highway mileage is:
# manufacturer          volkswagen
# model                      jetta
# displ                        1.9
# year                        1999
# cyl                            4
# trans                 manual(m5)
# drv                            f
# city                          33
# highway                       44
# fl                             d
# class                    compact
# ...

# %% [markdown]
# Create a column named average_mileage that is the mean of the city and highway mileage.

# %%
mpg['average_mileage']=(mpg.city+mpg.highway)/2

# %% [markdown]
# Which dodge car has the best average mileage? The worst?

# %%
print(f"Dodge car with best average mileage is:\n{mpg[mpg['manufacturer'] == 'dodge'].sort_values('average_mileage').iloc[0]}")
print(f"\n---\nDodge car with worst mileage is: \n{mpg[mpg['manufacturer'] == 'dodge'].sort_values('average_mileage').iloc[-1]}")
# Out:
# Dodge car with best average mileage is:
# manufacturer                        dodge
# model                 ram 1500 pickup 4wd
# displ                                 4.7
# year                                 2008
# cyl                                     8
# trans                          manual(m6)
# drv                                     4
# city                                    9
# highway                                12
# fl                                      e
# class                              pickup
# mileage_difference                      3
# average_mileage                      10.5
# Name: 70, dtype: object
#
# ---
# Dodge car with worst mileage is:
# manufacturer                dodge
# model                 caravan 2wd
# displ                         2.4
# year                         1999
# cyl                             4
# trans                    auto(l3)
# drv                             f
# city                           18
# ...

# %% [markdown]
# ## Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:

# %%
mammals = data('Mammals')

# %%
mammals = data('Mammals',show_doc=True)
# Out:
# Mammals
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Garland(1983) Data on Running Speed of Mammals
#
# ### Description
#
# Observations on the maximal running speed of mammal species and their body
# mass.
#
# ### Usage
#
#     data(Mammals)
#
# ### Format
#
# A data frame with 107 observations on the following 4 variables.
#
# weight
#
# Body mass in Kg for "typical adult sizes"
#
# speed
#
# Maximal running speed (fastest sprint velocity on record)
#
# hoppers
#
# logical variable indicating animals that ambulate by hopping, e.g. kangaroos
#
# specials
#
# logical variable indicating special animals with "lifestyles in which speed
# does not figure as an important factor": Hippopotamus, raccoon (Procyon),
# badger (Meles), coati (Nasua), skunk (Mephitis), man (Homo), porcupine
# (Erithizon), oppossum (didelphis), and sloth (Bradypus)
#
# ### Details
#
# ...

# %%
How many rows and columns are there?

# %%
mammals.shape
# Out:
# (107, 4)

# %% [markdown]
# What are the data types?

# %%
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %% [markdown]
# Summarize the dataframe with .info and .describe

# %%
mammals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 1 to 107
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   weight    107 non-null    float64
#  1   speed     107 non-null    float64
#  2   hoppers   107 non-null    bool
#  3   specials  107 non-null    bool
# dtypes: bool(2), float64(2)
# memory usage: 2.7 KB

# %%
mammals.describe()
# Out:
#             weight       speed
# count   107.000000  107.000000
# mean    278.688178   46.208411
# std     839.608269   26.716778
# min       0.016000    1.600000
# 25%       1.700000   22.500000
# 50%      34.000000   48.000000
# 75%     142.500000   65.000000
# max    6000.000000  110.000000

# %% [markdown]
# What is the the weight of the fastest animal?

# %%
print(f"The weight of the fastest animal is: {mammals[mammals.speed == max(mammals.speed)].weight.array[0]}")
# Out:
# The weight of the fastest animal is: 55.0

# %% [markdown]
# What is the overall percentage of specials?

# %%
100*sum(mammals.specials)/len(mammals)
# Out:
# 9.345794392523365

# %% [markdown]
# How many animals are hoppers that are above the median speed? What percentage is this?

# %%
hot_hoppers = sum(mammals[mammals.hoppers].speed > mammals.speed.median())
total_hoppers = sum(mammals.hoppers)
total_animals = len(mammals)
print(f"Hoppers above median speed: {hot_hoppers}. This is {round(100*hot_hoppers/total_animals,2)}% of all animals and {round(100*hot_hoppers/total_hoppers,2)}% of all hoppers")
# Out:
# Hoppers above median speed: 7. This is 6.54% of all animals and 63.64% of all hoppers
